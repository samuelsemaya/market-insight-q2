# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('Sample Data Technical Test Markethac Aug 2024.csv')

# %%
df.head()
# Out:
#          date               itemid channel  \
# 0  2023-05-08  1729385653806401294  Tiktok
# 1  2023-05-08  1729510593066469833  Tiktok
# 2  2023-05-08  1729582821264689500  Tiktok
# 3  2023-05-08          11804054885  Shopee
# 4  2023-05-08          21120947258  Shopee
#
#                                          listingname  salescount  \
# 0                  Sunscren Madame gie SPF 30 PA +++         452
# 1  SKINTIFIC All Day Light Sunscreen Mist SPF50 P...         183
# 2  LAMEILA SVMY Sunscreen Sun Block Wajah SPF 50 ...          61
# 3     EMINA  Sun Battle SPF 30 PA+++ sunscreen 60 ml         873
# 4  FACETOLOGY Triple Care Sunscreen SPF 40+ PA+++...          14
#
#    daily_sales_count  daily_sales_value              categorychannel  \
# 0                  3              98262  Facial Sunscreen & Sun Care
# 1                  1              89600  Facial Sunscreen & Sun Care
# 2                  2              25200  Facial Sunscreen & Sun Care
# ...

# %%
df_1 = df.sample(frac=0.1, random_state=42)

# %%
df_1.shape
# Out:
# (98139, 19)

# %%
df_1.to_csv('sample_test.csv')
